# %%
#! pip install nltk

# %%
import nltk
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\SPLPT
# [nltk_data]     959\AppData\Roaming\nltk_data...
# True

# %%
import re # Regular Expression
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

# %%
sample_text="""The WikiQA corpus is a new publicly available set of question and sentence pairs, collected and annotated for research on open-domain question answering. In order to reflect the true information need of general users, we used Bing query logs as the question source. Each question is linked to a Wikipedia page that potentially has the answer. Because the summary section of a Wikipedia page provides the basic and usually most important information about the topic, we used sentences in this section as the candidate answers. With the help of crowdsourcing, we included 3,047 questions and 29,258 sentences in the dataset, where 1,473 sentences were labeled as answer sentences to their corresponding questions. More detail of this corpus can be found in our EMNLP-2015 paper, "WikiQA: A Challenge Dataset for Open-Domain Question Answering" [Yang et al. 2015]. In addition, this download also includes the experimental results in the paper, an evaluation script for judging the "answer triggering" task, as well as the answer phrases labeled by the authors of the paper."""

# %%
sample_text = sample_text.lower()
sample_text
# Out:
# 'the wikiqa corpus is a new publicly available set of question and sentence pairs, collected and annotated for research on open-domain question answering. in order to reflect the true information need of general users, we used bing query logs as the question source. each question is linked to a wikipedia page that potentially has the answer. because the summary section of a wikipedia page provides the basic and usually most important information about the topic, we used sentences in this section as the candidate answers. with the help of crowdsourcing, we included 3,047 questions and 29,258 sentences in the dataset, where 1,473 sentences were labeled as answer sentences to their corresponding questions. more detail of this corpus can be found in our emnlp-2015 paper, "wikiqa: a challenge dataset for open-domain question answering" [yang et al. 2015]. in addition, this download also includes the experimental results in the paper, an evaluation script for judging the "answer triggering
# ...

# %%
sample_tokens = word_tokenize(sample_text)
sample_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
# ...

# %%
#import nltk
#nltk.download('all')

# %%
import pickle
with open("sample_tokens.pkl","wb") as mf:
    pickle.dump(sample_tokens,mf)

# %% [markdown]
# # Stopwords removal

# %%
type(stopwords.words('english'))
# Out:
# list

# %%
stop_words = stopwords.words('english')

# %%
stop_words = set(stop_words)

# %%
sr_list = []
for i in sample_tokens:
    if i not in stop_words:
        print(i)
        sr_list.append(i)
# Out:
# wikiqa
# corpus
# new
# publicly
# available
# set
# question
# sentence
# pairs
# ,
# collected
# annotated
# research
# open-domain
# question
# answering
# .
# order
# reflect
# true
# information
# need
# general
# users
# ,
# used
# bing
# query
# logs
# question
# source
# .
# question
# linked
# wikipedia
# page
# potentially
# answer
# .
# summary
# section
# wikipedia
# page
# provides
# basic
# usually
# important
# information
# topic
# ,
# used
# sentences
# section
# candidate
# answers
# .
# help
# crowdsourcing
# ,
# included
# 3,047
# questions
# 29,258
# sentences
# dataset
# ,
# 1,473
# sentences
# labeled
# answer
# sentences
# corresponding
# questions
# .
# detail
# corpus
# found
# emnlp-2015
# paper
# ,
# ``
# wikiqa
# :
# challenge
# dataset
# open-domain
# question
# answering
# ''
# [
# yang
# et
# al
# .
# 2015
# ]
# .
# addition
# ,
# download
# also
# includes
# experimental
# results
# paper
# ,
# evaluation
# script
# judging
# ``
# answer
# triggering
# ...

# %%
sr_list = [i for i in sample_tokens if i not in stop_words ]

# %%
sr_list
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  '3,047',
#  'questions',
#  '29,258',
#  'sentences',
#  'dataset',
#  ',',
#  '1,473',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
# ...

# %%
sample_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
# ...

# %% [markdown]
# # Number Removal

# %%
input_string = ' '.join(sr_list)

# %%
re.sub(r'\d+', ' ',input_string)
# Out:
# "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %% [markdown]
# # Spl Char Removal % Punctations

# %%
std_tokens = ['the',
 'wikiqa',
 'corpus',
 'is',
 'a',
 'new',
 'publicly',
 'available',
 'set',
 'of',
 'question',
 'and',
 'sentence',
 'pairs',
 ',',
 'collected',
 'and',
 'annotated',
 'for',
 'research',
 'on',
 'open-domain',
 'question',
 'answering',
 '.',
 'in',
 'order',
 'to',
 'reflect',
 'the',
 'true',
 'information',
 'need',
 'of',
 'general',
 'users',
 ',',
 'we',
 'used',
 'bing',
 'query',
 'logs',
 'as',
 'the',
 'question',
 'source',
 '.',
 'each',
 'question',
 'is',
 'linked',
 'to',
 'a',
 'wikipedia',
 'page',
 'that',
 'potentially',
 'has',
 'the',
 'answer',
 '.',
 'because',
 'the',
 'summary',
 'section',
 'of',
 'a',
 'wikipedia',
 'page',
 'provides',
 'the',
 'basic',
 'and',
 'usually',
 'most',
 'important',
 'information',
 'about',
 'the',
 'topic',
 ',',
 'we',
 'used',
 'sentences',
 'in',
 'this',
 'section',
 'as',
 'the',
 'candidate',
 'answers',
 '.',
 'with',
 'the',
 'help',
 'of',
 'crowdsourcing',
 ',',
 'we',
 'included',
 '3,047',
 'questions',
 'and',
 '29,258',
 'sentences',
 'in',
 'the',
 'dataset',
 ',',
 'where',
 '1,473',
 'sentences',
 'were',
 'labeled',
 'as',
 'answer',
 'sentences',
 'to',
 'their',
 'corresponding',
 'questions',
 '.',
 'more',
 'detail',
 'of',
 'this',
 'corpus',
 'can',
 'be',
 'found',
 'in',
 'our',
 'emnlp-2015',
 'paper',
 ',',
 '``',
 'wikiqa',
 ':',
 'a',
 'challenge',
 'dataset',
 'for',
 'open-domain',
 'question',
 'answering',
 "''",
 '[',
 'yang',
 'et',
 'al',
 '.',
 '2015',
 ']',
 '.',
 'in',
 'addition',
 ',',
 'this',
 'download',
 'also',
 'includes',
 'the',
 'experimental',
 'results',
 'in',
 'the',
 'paper',
 ',',
 'an',
 'evaluation',
 'script',
 'for',
 'judging',
 'the',
 '``',
 'answer',
 'triggering',
 "''",
 'task',
 ',',
 'as',
 'well',
 'as',
 'the',
 'answer',
 'phrases',
 'labeled',
 'by',
 'the',
 'authors',
 'of',
 'the',
 'paper',
 '.']

# %%
[re.sub(r'[^a-zA-Z0-9]', '', i )  for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  '',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'opendomain',
#  'question',
#  'answering',
#  '',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  '',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  '',
#  'we',
#  'used',
#  'sentences',
#  'in',
# ...

# %%
[re.sub(r'\w+', '', i )  for i in std_tokens]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  ',',
#  '``',
#  '',
#  ':',
#  '',
#  '',
# ...

# %% [markdown]
# # Spell checking

# %%
#! pip install pyspellchecker

# %%
from spellchecker import SpellChecker

# %%
checker = SpellChecker()

# %%
[checker.correction(i) for i in std_tokens]
# Out:
# ['the',
#  'wiki',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  None,
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'being',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  None,
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  None,
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
#  'in',
#  'this',
# ...

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
stemmer = PorterStemmer()

# %%
std_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
# ...

# %%
[stemmer.stem(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpu',
#  'is',
#  'a',
#  'new',
#  'publicli',
#  'avail',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentenc',
#  'pair',
#  ',',
#  'collect',
#  'and',
#  'annot',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answer',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'inform',
#  'need',
#  'of',
#  'gener',
#  'user',
#  ',',
#  'we',
#  'use',
#  'bing',
#  'queri',
#  'log',
#  'as',
#  'the',
#  'question',
#  'sourc',
#  '.',
#  'each',
#  'question',
#  'is',
#  'link',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potenti',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'becaus',
#  'the',
#  'summari',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provid',
#  'the',
#  'basic',
#  'and',
#  'usual',
#  'most',
#  'import',
#  'inform',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'use',
#  'sentenc',
#  'in',
#  'thi',
#  'section',
#  'as',
#  'the',
# ...

# %% [markdown]
# # Lemmatizer

# %%
lemm = WordNetLemmatizer()

# %%
std_tokens
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'users',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'as',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'has',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentences',
# ...

# %%
[lemm.lemmatize(i) for i in std_tokens]
# Out:
# ['the',
#  'wikiqa',
#  'corpus',
#  'is',
#  'a',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'of',
#  'question',
#  'and',
#  'sentence',
#  'pair',
#  ',',
#  'collected',
#  'and',
#  'annotated',
#  'for',
#  'research',
#  'on',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'in',
#  'order',
#  'to',
#  'reflect',
#  'the',
#  'true',
#  'information',
#  'need',
#  'of',
#  'general',
#  'user',
#  ',',
#  'we',
#  'used',
#  'bing',
#  'query',
#  'log',
#  'a',
#  'the',
#  'question',
#  'source',
#  '.',
#  'each',
#  'question',
#  'is',
#  'linked',
#  'to',
#  'a',
#  'wikipedia',
#  'page',
#  'that',
#  'potentially',
#  'ha',
#  'the',
#  'answer',
#  '.',
#  'because',
#  'the',
#  'summary',
#  'section',
#  'of',
#  'a',
#  'wikipedia',
#  'page',
#  'provides',
#  'the',
#  'basic',
#  'and',
#  'usually',
#  'most',
#  'important',
#  'information',
#  'about',
#  'the',
#  'topic',
#  ',',
#  'we',
#  'used',
#  'sentence',
#  'in',
# ...

# %% [markdown]
# # POS

# %%
import nltk

# %%
input_sent = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
tokens = nltk.word_tokenize(input_sent)

# %%
tokens
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
# ...

# %%
pos_tagged_words = nltk.pos_tag(tokens)

# %%
noun_list = []
non_noun = []
for i,j in pos_tagged_words:
    if j not in ['PRP','NN']:
        print(i)
        non_noun.append(i)
    else:
        print(i)
        noun_list.append(i)
# Out:
# wikiqa
# corpus
# new
# publicly
# available
# set
# question
# sentence
# pairs
# ,
# collected
# annotated
# research
# open-domain
# question
# answering
# .
# order
# reflect
# true
# information
# need
# general
# users
# ,
# used
# bing
# query
# logs
# question
# source
# .
# question
# linked
# wikipedia
# page
# potentially
# answer
# .
# summary
# section
# wikipedia
# page
# provides
# basic
# usually
# important
# information
# topic
# ,
# used
# sentences
# section
# candidate
# answers
# .
# help
# crowdsourcing
# ,
# included
# ,
# questions
# ,
# sentences
# dataset
# ,
# ,
# sentences
# labeled
# answer
# sentences
# corresponding
# questions
# .
# detail
# corpus
# found
# emnlp-
# paper
# ,
# ``
# wikiqa
# :
# challenge
# dataset
# open-domain
# question
# answering
# ``
# [
# yang
# et
# al
# .
# ]
# .
# addition
# ,
# download
# also
# includes
# experimental
# results
# paper
# ,
# evaluation
# script
# judging
# ``
# answer
# triggering
# ``
# task
# ,
# well
# ...

# %% [markdown]
# # N grams

# %%
from nltk.util import ngrams

# %%
input_text = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
input_text
tokens = word_tokenize(input_text)

# %%
len(tokens)
# Out:
# 121

# %%
ngrams(tokens,2)

# %%
gram_2 = list(ngrams(tokens,2))

# %%
gram_2
# Out:
# [('wikiqa', 'corpus'),
#  ('corpus', 'new'),
#  ('new', 'publicly'),
#  ('publicly', 'available'),
#  ('available', 'set'),
#  ('set', 'question'),
#  ('question', 'sentence'),
#  ('sentence', 'pairs'),
#  ('pairs', ','),
#  (',', 'collected'),
#  ('collected', 'annotated'),
#  ('annotated', 'research'),
#  ('research', 'open-domain'),
#  ('open-domain', 'question'),
#  ('question', 'answering'),
#  ('answering', '.'),
#  ('.', 'order'),
#  ('order', 'reflect'),
#  ('reflect', 'true'),
#  ('true', 'information'),
#  ('information', 'need'),
#  ('need', 'general'),
#  ('general', 'users'),
#  ('users', ','),
#  (',', 'used'),
#  ('used', 'bing'),
#  ('bing', 'query'),
#  ('query', 'logs'),
#  ('logs', 'question'),
#  ('question', 'source'),
#  ('source', '.'),
#  ('.', 'question'),
#  ('question', 'linked'),
#  ('linked', 'wikipedia'),
#  ('wikipedia', 'page'),
#  ('page', 'potentially'),
#  ('potentially', 'answer'),
#  ('answer', '.'),
#  ('.', 'summary'),
# ...

# %%
gram_3 = list(ngrams(tokens,3))

# %%
gram_3
# Out:
# [('wikiqa', 'corpus', 'new'),
#  ('corpus', 'new', 'publicly'),
#  ('new', 'publicly', 'available'),
#  ('publicly', 'available', 'set'),
#  ('available', 'set', 'question'),
#  ('set', 'question', 'sentence'),
#  ('question', 'sentence', 'pairs'),
#  ('sentence', 'pairs', ','),
#  ('pairs', ',', 'collected'),
#  (',', 'collected', 'annotated'),
#  ('collected', 'annotated', 'research'),
#  ('annotated', 'research', 'open-domain'),
#  ('research', 'open-domain', 'question'),
#  ('open-domain', 'question', 'answering'),
#  ('question', 'answering', '.'),
#  ('answering', '.', 'order'),
#  ('.', 'order', 'reflect'),
#  ('order', 'reflect', 'true'),
#  ('reflect', 'true', 'information'),
#  ('true', 'information', 'need'),
#  ('information', 'need', 'general'),
#  ('need', 'general', 'users'),
#  ('general', 'users', ','),
#  ('users', ',', 'used'),
#  (',', 'used', 'bing'),
#  ('used', 'bing', 'query'),
#  ('bing', 'query', 'logs'),
#  ('query', 'logs', 'question'),
# ...

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sample_text = "wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions . detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."

# %%
word_tokenize(sample_text)
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
# ...

# %%
tokens = word_tokenize(sample_text)

# %%
tokens
# Out:
# ['wikiqa',
#  'corpus',
#  'new',
#  'publicly',
#  'available',
#  'set',
#  'question',
#  'sentence',
#  'pairs',
#  ',',
#  'collected',
#  'annotated',
#  'research',
#  'open-domain',
#  'question',
#  'answering',
#  '.',
#  'order',
#  'reflect',
#  'true',
#  'information',
#  'need',
#  'general',
#  'users',
#  ',',
#  'used',
#  'bing',
#  'query',
#  'logs',
#  'question',
#  'source',
#  '.',
#  'question',
#  'linked',
#  'wikipedia',
#  'page',
#  'potentially',
#  'answer',
#  '.',
#  'summary',
#  'section',
#  'wikipedia',
#  'page',
#  'provides',
#  'basic',
#  'usually',
#  'important',
#  'information',
#  'topic',
#  ',',
#  'used',
#  'sentences',
#  'section',
#  'candidate',
#  'answers',
#  '.',
#  'help',
#  'crowdsourcing',
#  ',',
#  'included',
#  ',',
#  'questions',
#  ',',
#  'sentences',
#  'dataset',
#  ',',
#  ',',
#  'sentences',
#  'labeled',
#  'answer',
#  'sentences',
#  'corresponding',
#  'questions',
#  '.',
#  'detail',
#  'corpus',
# ...

# %%
sent_tokenize(sample_text)
# Out:
# ['wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering .',
#  'order reflect true information need general users , used bing query logs question source .',
#  'question linked wikipedia page potentially answer .',
#  'summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers .',
#  'help crowdsourcing , included  ,  questions  ,  sentences dataset ,  ,  sentences labeled answer sentences corresponding questions .',
#  "detail corpus found emnlp-  paper , `` wikiqa : challenge dataset open-domain question answering '' [ yang et al .   ]",
#  '.',
#  "addition , download also includes experimental results paper , evaluation script judging `` answer triggering '' task , well answer phrases labeled authors paper ."]

# %%
" ".join(tokens)
# Out:
# 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %% [markdown]
# # Text Classification

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer # Term Frequency 
from sklearn.metrics import classification_report

# %%
data = pd.read_csv("test.csv")

# %%
data
# Out:
#                                                    text  label
# 0     I always wrote this series off as being a comp...      0
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2     This movie was so poorly written and directed ...      0
# 3     The most interesting thing about Miryang (Secr...      1
# 4     when i first read about "berlin am meer" i did...      0
# ...                                                 ...    ...
# 4995  This is the kind of picture John Lassiter woul...      1
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998  This movie is a clumsy mishmash of various gho...      0
# 4999  Formula movie about the illegitimate son of a ...      0
#
# [5000 rows x 2 columns]

# %%
data_text = data['text']
data_targ = data['label']

# %%
vect  = TfidfVectorizer()

# %%
train_data = vect.fit_transform(data_text)

# %%
len(vect.get_feature_names_out())
# Out:
# 39126

# %%
len(train_data.toarray()[0])
# Out:
# 39126

# %%
model = SVC(kernel="linear")

# %%
model.fit(train_data,data_targ)
# Out:
# SVC(kernel='linear')

# %%
predicted_data = model.predict(train_data)

# %%
print(classification_report(data_targ, predicted_data))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2495
#            1       0.98      0.98      0.98      2505
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sent = 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
sent
# Out:
# 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
sent_ment = SentimentIntensityAnalyzer()

# %%
sent_score = sent_ment.polarity_scores(sent)

# %%
sent_score
# Out:
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.8689}

# %%
sent_score['compound']
# Out:
# 0.8689

# %% [markdown]
# # Word Cloud

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
w_c = WordCloud(width=1000,height=500,background_color="green").generate(sent)

plt.figure(figsize=(14,6))
plt.imshow(w_c)
plt.axis('off')
plt.show()

# %%
w_c

# %% [markdown]
# # Keyword extraction

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
input_text = 'wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
vect = CountVectorizer(stop_words="english")

# %%
ext_val = vect.fit_transform([input_text])

# %%
vect.get_feature_names_out()
# Out:
# array(['addition', 'al', 'annotated', 'answer', 'answering', 'answers',
#        'authors', 'available', 'basic', 'bing', 'candidate', 'challenge',
#        'collected', 'corpus', 'corresponding', 'crowdsourcing', 'dataset',
#        'domain', 'download', 'emnlp', 'et', 'evaluation', 'experimental',
#        'general', 'help', 'important', 'included', 'includes',
#        'information', 'judging', 'labeled', 'linked', 'logs', 'need',
#        'new', 'open', 'order', 'page', 'pairs', 'paper', 'phrases',
#        'potentially', 'provides', 'publicly', 'query', 'question',
#        'questions', 'reflect', 'research', 'results', 'script', 'section',
#        'sentence', 'sentences', 'set', 'source', 'summary', 'task',
#        'topic', 'triggering', 'true', 'used', 'users', 'usually',
#        'wikipedia', 'wikiqa', 'yang'], dtype=object)

# %% [markdown]
# # Name Entity Recognition

# %%
import spacy

# %%
#!pip install spacy

# %%
#!python -m spacy download en_core_web_sm

# %%
# Load spaCy English language model
nlp = spacy.load("en_core_web_sm")

# %%
# Sample text for NER
text ='wikiqa corpus new publicly available set question sentence pairs , collected annotated research open-domain question answering . order reflect true information need general users , used bing query logs question source . question linked wikipedia page potentially answer . summary section wikipedia page provides basic usually important information topic , used sentences section candidate answers . help crowdsourcing , included , questions , sentences dataset , , sentences labeled answer sentences corresponding questions . detail corpus found emnlp- paper , `` wikiqa : challenge dataset open-domain question answering `` [ yang et al . ] . addition , download also includes experimental results paper , evaluation script judging `` answer triggering `` task , well answer phrases labeled authors paper .'

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(f"Entity: {ent.text}, Type: {ent.label_}")
# Out:
# Entity: [ yang et al . ] ., Type: WORK_OF_ART
